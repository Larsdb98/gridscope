# %% [markdown]
# # Raw Weather Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("data/weather/uk_raw_weather_sites_start-2024-01-01_end-2024-12-31.csv")
# print(df.info())
# print(f"Column list: {df.columns.to_list()}")
# print(df.head())

df_subset = df[(df['datetime']>='2024-01-01') & (df['datetime']<'2024-01-08')]
print(df_subset)
# Out:
#                 datetime  temp_site1  humidity_site1  precip_site1  \
# 0    2024-01-01 00:00:00        7.60            77.0           0.0
# 1    2024-01-01 00:30:00        7.50            77.5           0.0
# 2    2024-01-01 01:00:00        7.40            78.0           0.0
# 3    2024-01-01 01:30:00        7.25            79.0           0.0
# 4    2024-01-01 02:00:00        7.10            80.0           0.0
# ..                   ...         ...             ...           ...
# 139  2024-01-03 21:30:00        6.65            93.0           0.0
# 140  2024-01-03 22:00:00        6.50            93.0           0.0
# 141  2024-01-03 22:30:00        6.40            93.0           0.0
# 142  2024-01-03 23:00:00        6.30            93.0           0.0
# 143  2024-01-03 23:30:00        6.25            93.0           0.0
#
#      dewpoint_site1  pressure_site1  cloud_site1  temp_site2  humidity_site2  \
# 0              3.80          995.00         60.0        6.70            83.0
# 1              3.85          995.55         41.0        6.35            84.5
# 2              3.90          996.10         22.0        6.00            86.0
# 3              3.90          996.55         27.5        6.00            85.0
# 4              3.90          997.00         33.0        6.00            84.0
# ..              ...             ...          ...         ...             ...
# 139            5.55          996.85          5.0        5.70            94.0
# 140            5.40          997.40         10.0        5.60            94.0
# 141            5.35          997.80         10.0        5.60            94.0
# 142            5.30          998.20         10.0        5.60            94.0
# 143            5.20          998.55         12.0        5.65            94.0
#
#      precip_site2  ...  pressure_site_solar6  temp_site_solar6  \
# 0             0.0  ...                999.70              8.20
# 1             0.0  ...               1000.15              8.00
# 2             0.0  ...               1000.60              7.80
# 3             0.0  ...               1001.00              7.70
# 4             0.0  ...               1001.40              7.60
# ..            ...  ...                   ...               ...
# 139           0.0  ...               1000.25              8.45
# 140           0.0  ...               1000.80              8.30
# 141           0.0  ...               1001.10              8.10
# 142           0.0  ...               1001.40              7.90
# 143           0.0  ...               1001.70              7.75
#
#      humidity_site_solar6  precip_site_solar6  solar_rad_site7  \
# 0                    72.0                 0.0              0.0
# 1                    74.5                 0.1              0.0
# 2                    77.0                 0.2              0.0
# 3                    73.5                 0.1              0.0
# 4                    70.0                 0.0              0.0
# ..                    ...                 ...              ...
# 139                  82.5                 0.0              0.0
# 140                  81.0                 0.0              0.0
# 141                  79.0                 0.0              0.0
# 142                  77.0                 0.0              0.0
# 143                  78.5                 0.0              0.0
#
#      cloud_site_solar7  pressure_site_solar7  temp_site_solar7  \
# 0                 33.0                995.20               7.3
# 1                 36.0                995.80               7.2
# 2                 39.0                996.40               7.1
# 3                 33.0                997.00               7.1
# 4                 27.0                997.60               7.1
# ..                 ...                   ...               ...
# 139               45.0                997.80               6.9
# 140               62.0                998.20               7.0
# 141               43.0                998.45               7.3
# 142               24.0                998.70               7.6
# 143               20.0                999.00               7.4
#
#      humidity_site_solar7  precip_site_solar7
# 0                    77.0                 0.0
# 1                    77.5                 0.0
# 2                    78.0                 0.0
# 3                    78.0                 0.0
# 4                    78.0                 0.0
# ..                    ...                 ...
# 139                  92.0                 0.0
# 140                  92.0                 0.0
# 141                  90.0                 0.0
# 142                  88.0                 0.0
# 143                  88.0                 0.0
#
# [144 rows x 151 columns]

# %%
plt.plot(df_subset["temp_site1"])
